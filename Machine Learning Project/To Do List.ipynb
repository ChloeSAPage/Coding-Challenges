# %% [markdown]
# # To Do List

# %% [markdown]
# - [x] data
# preparation

# %% [markdown]
# - [x] data checks

# %% [markdown]
# - [x] feature analysis

# %% [markdown]
# - [x] model selection

# %% [markdown]
# - [x] model assessment

# %% [markdown]
# - [ ] model optimisation

# %% [markdown]
# Classification problem - binary - logistic regression? - categorical predicted values.

# %% [markdown]
# Not linear regression - for continuous predicted values

# %% [markdown]
# Cleaning data - removing outliers? or irrelevant columns?

# %% [markdown]
# work out mean/median/mode/range to find the trends between column and cohort.

# %% [markdown]
# scatter plots to see trends in the data between cohort and skill/place/quest

# %% [markdown]
# split data into 2, 1 test set and 1 training set. - train_test_split?

# %% [markdown]
# train size - 0.3?, 0.5?, 0.7?

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d02cd21e-d2ae-4cbc-bbea-b863e71e91a2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
